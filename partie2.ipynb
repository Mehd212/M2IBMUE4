# %%
import pandas as pd
import os
import re

# %%
# Function to parse SRT file into a DataFrame
def parse_srt_to_dataframe(srt_file_path):
    with open(srt_file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    
    # Split into subtitle blocks
    blocks = content.strip().split('\n\n')
    
    # Parse blocks
    data = []
    index = 1
    for block in blocks:
        lines = block.split('\n')
        timing = lines[1]
        start_time, end_time = timing.split(' --> ')
        start_time = start_time.split(" ")[0]
        end_time = end_time.split(" ")[0]
        text = ' '.join(lines[2:])  # Subtitle text
        data.append([index, start_time, end_time, text])
        index += 1
    
    # Create a DataFrame
    srt_df = pd.DataFrame(data, columns=['Index', 'Start Time', 'End Time', 'Text'])
    srt_df["Index"] = srt_df["Index"].astype("int")
    return srt_df

# Function to parse RTTM file into a DataFrame with Index
def parse_rttm_to_dataframe(rttm_file_path):
    # Define columns for RTTM
    columns = ["Type", "File ID", "Channel", "Start Time", "Duration", 
               "Orthography", "Speaker Type", "Speaker ID", "Confidence1", "Confidence2"]
    
    # Read the RTTM file
    with open(rttm_file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()
    
    # Parse rows
    data = []
    for idx, line in enumerate(lines):
        if line.strip() and not line.startswith('#'):  # Skip empty or commented lines
            row = line.strip().split()
            row.insert(0, idx + 1)  # Add an index as the first column
            data.append(row)
    
    # Update columns to include "Index"
    columns.insert(0, "Index")
    
    # Create a DataFrame
    rttm_df = pd.DataFrame(data, columns=columns)
    return rttm_df

# %%
# Paths to your SRT and RTTM files
srt_file_path = 'data/dj_2022_3_mois_paracetamol/dj_2022_3_mois_paracetamol.srt'
rttm_file_path = 'data/dj_2022_3_mois_paracetamol/dj_2022_3_mois_paracetamol.rttm'

# %%
def get_conversation(srt_file_path, rttm_file_path):
    srt_df = parse_srt_to_dataframe(srt_file_path)
    rttm_df = parse_rttm_to_dataframe(rttm_file_path)
    srt_df["Speaker ID"] = rttm_df["Index"].map(rttm_df.set_index("Index")["Speaker ID"])
    srt_df["File"] = srt_file_path.rsplit("/", 1)[1].split(".")[0]
    return srt_df

get_conversation(srt_file_path, rttm_file_path)
# Out:
#     Index    Start Time      End Time  \
# 0       1  00:00:03,449  00:00:04,149
# 1       2  00:00:04,250  00:00:05,049
# 2       3  00:00:05,399  00:00:06,430
# 3       4  00:00:06,449  00:00:11,090
# 4       5  00:00:11,529  00:00:13,779
# 5       6  00:00:14,000  00:00:16,059
# 6       7  00:00:16,360  00:00:20,150
# 7       8  00:00:20,450  00:00:27,150
# 8       9  00:00:27,859  00:00:32,500
# 9      10  00:00:32,500  00:00:34,150
# 10     11  00:00:34,590  00:00:36,110
# 11     12  00:00:36,640  00:00:40,370
# 12     13  00:00:40,700  00:00:43,750
# 13     14  00:00:44,420  00:00:59,220
# 14     15  00:01:00,190  00:01:01,310
# 15     16  00:01:01,310  00:01:02,250
# 16     17  00:01:02,250  00:01:09,120
# 17     18  00:01:09,750  00:01:12,610
# 18     19  00:01:12,610  00:01:18,020
# 19     20  00:01:18,030  00:01:20,890
# 20     21  00:01:20,910  00:01:25,550
# 21     22  00:01:26,110  00:01:29,530
# 22     23  00:01:29,700  00:01:32,330
# 23     24  00:01:32,520  00:01:34,610
# 24     25  00:01:34,690  00:01:35,430
# 25     26  00:01:36,250  00:01:45,700
# 26     27  00:01:46,530  00:01:48,250
# 27     28  00:01:48,650  00:01:58,320
# 28     29  00:01:58,320  00:02:02,110
# 29     30  00:02:02,570  00:02:03,220
# 30     31  00:02:03,220  00:02:04,560
# 31     32  00:02:04,619  00:02:08,320
# 32     33  00:02:08,899  00:02:09,539
# 33     34  00:02:09,709  00:02:10,399
# 34     35  00:02:10,759  00:02:11,600
#
#                                                  Text Speaker ID  \
# 0                                               allo?    patient
# 1                                        allo madame?    medecin
# 2                                     oui allo, allo?    patient
# 3   oui bonjour je suis le docteur LAKHLIFI. vous ...    medecin
# 4                   oui c'est ça c'est ça, exactement    patient
# 5           ça fait heu j'attends depuis longtemps là    patient
# 6   hum d'accord. il a pris des médicaments qu'il ...    medecin
# 7   oui c'est ça c'est ça, je pense heu ça fait be...    patient
# 8   je je heu j'en suis vraiment désolée. on on va...    medecin
# 9                   oui mais moi j'attends quoi, hein    patient
# 10                       quel médicament a-t-il pris?    medecin
# 11      bah c'est du para- paracétamol là vous savez?    patient
# 12  oui tout à fait. en quelle dose il l'a il l'a ...    medecin
# 13  bah je sais pas enfin moi euh j'ai l'habi-, en...    patient
# 14                           je comprends tout à fait    medecin
# 15                    qu'est ce que je dois faire là?    patient
# 16  vous restez vous restez avec votre enfant, vou...    medecin
# 17  mais moi là il faut que je donne quoi? qu'est ...    patient
# 18  il faut donner absolument rien à votre enfant....    medecin
# 19  oui mais est ce qu'il faut le faire vomir? on ...    patient
# 20  non, il ne faut pas il faut pas le faire vomir...    medecin
# 21  d'accord ils arrivent dans combien de temps? p...    patient
# 22      ils vont arriver dans moins de quinze minutes    medecin
# 23           moins de quinze minutes? vous êtes sûre?    patient
# 24                                       je suis sûre    medecin
# 25  n'hésitez pas à nous rappeler si heu il y a qu...    medecin
# 26          c'est quoi un autre problème par exemple?    patient
# 27  par exemple heu si heu vous voyez il devient t...    medecin
# 28  je suis inquiète, je suis inquiète, c'est depu...    patient
# 29                              je comprends et c'est    medecin
# 30                 je répète trois fois la même chose    patient
# 31  c'est heu c'est pour ça qu'on envoie les secou...    medecin
# 32                                           d'accord    patient
# 33                                          au revoir    medecin
# 34                                    merci au revoir    patient
#
#                           File
# 0   dj_2022_3_mois_paracetamol
# 1   dj_2022_3_mois_paracetamol
# 2   dj_2022_3_mois_paracetamol
# 3   dj_2022_3_mois_paracetamol
# 4   dj_2022_3_mois_paracetamol
# 5   dj_2022_3_mois_paracetamol
# 6   dj_2022_3_mois_paracetamol
# 7   dj_2022_3_mois_paracetamol
# 8   dj_2022_3_mois_paracetamol
# 9   dj_2022_3_mois_paracetamol
# 10  dj_2022_3_mois_paracetamol
# 11  dj_2022_3_mois_paracetamol
# 12  dj_2022_3_mois_paracetamol
# 13  dj_2022_3_mois_paracetamol
# 14  dj_2022_3_mois_paracetamol
# 15  dj_2022_3_mois_paracetamol
# 16  dj_2022_3_mois_paracetamol
# 17  dj_2022_3_mois_paracetamol
# 18  dj_2022_3_mois_paracetamol
# 19  dj_2022_3_mois_paracetamol
# 20  dj_2022_3_mois_paracetamol
# 21  dj_2022_3_mois_paracetamol
# 22  dj_2022_3_mois_paracetamol
# 23  dj_2022_3_mois_paracetamol
# 24  dj_2022_3_mois_paracetamol
# 25  dj_2022_3_mois_paracetamol
# 26  dj_2022_3_mois_paracetamol
# 27  dj_2022_3_mois_paracetamol
# 28  dj_2022_3_mois_paracetamol
# 29  dj_2022_3_mois_paracetamol
# 30  dj_2022_3_mois_paracetamol
# 31  dj_2022_3_mois_paracetamol
# 32  dj_2022_3_mois_paracetamol
# 33  dj_2022_3_mois_paracetamol
# 34  dj_2022_3_mois_paracetamol

# %%
folders = os.listdir("./data")
conversations = []
for folder in data_folders:
    srt_file = list(filter(re.compile(".*srt").match, os.listdir("./data/"+folder)))[0]
    rttm_file = list(filter(re.compile(".*rttm").match, os.listdir("./data/"+folder)))[0]
    conversations.append(get_conversation("./data/"+folder+"/"+srt_file, "./data/"+folder+"/"+rttm_file))
conversations = pd.concat(conversations)
conversations
# Out:
#     Index    Start Time      End Time  \
# 0       1  00:00:01,400  00:00:02,400
# 1       2  00:00:03,550  00:00:04,210
# 2       3  00:00:04,250  00:00:11,200
# 3       4  00:00:11,850  00:00:17,759
# 4       5  00:00:18,869  00:00:19,830
# ..    ...           ...           ...
# 53     54  00:03:08,950  00:03:09,660
# 54     55  00:03:10,160  00:03:10,920
# 55     56  00:03:10,930  00:03:11,170
# 56     57  00:03:12,820  00:03:13,350
# 57     58  00:03:13,440  00:03:13,790
#
#                                                  Text Speaker ID  \
# 0                                      bonjour madame    medecin
# 1                                             bonjour    patient
# 2   bonjour je suis le docteur ABAS du SAMU hum do...    medecin
# 3   ah bah elle a fait un malaise oui oui là elle ...    patient
# 4                              elle est inconsciente?    medecin
# ..                                                ...        ...
# 53                                           d'accord    patient
# 54                            à tout à l'heure madame    medecin
# 55                                                 ok    patient
# 56                                          au revoir    patient
# 57                                          au revoir    medecin
#
#               File
# 0   dj_mai_tetanie
# 1   dj_mai_tetanie
# 2   dj_mai_tetanie
# 3   dj_mai_tetanie
# 4   dj_mai_tetanie
# ..             ...
# 53    reu_brulures
# 54    reu_brulures
# 55    reu_brulures
# 56    reu_brulures
# 57    reu_brulures
#
# [3089 rows x 6 columns]
